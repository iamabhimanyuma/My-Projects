# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np

# %%
db_host  = '18.136.157.135'
Username = 'dm_usdata_sql' 
Password = '37z<49REb&mKnl4AV!vJ'
db_name  = 'project_service_data'

conn = create_engine('mysql+pymysql://'+Username+':'+Password+'@'+db_host+'/'+db_name)
conn.table_names()
# Out:
# ['service_data']

# %%
query = 'select * from service_data'
df = pd.read_sql(query,conn)
df.head()
# Out:
#   invoice_date job_card_date business_partner_name  vehicle_no  \
# 0     30-05-17      30-05-17        shivXXXXXXXXXX  KA03MFXXXX
# 1     02-06-17      31-05-17        KIRAXXXXXXXXXX  KA53ESXXXX
# 2     02-06-17      31-05-17        KIRAXXXXXXXXXX  KA53ESXXXX
# 3     02-06-17      31-05-17        KIRAXXXXXXXXXX  KA53ESXXXX
# 4     02-06-17      31-05-17        KIRAXXXXXXXXXX  KA53ESXXXX
#
#               vehicle_model current_km_reading invoice_line_text
# 0  BAJAJ AVENGER STREET 220              50000        ENGINE OIL
# 1       BAJAJ PULSAR NS 200                758        ENGINE OIL
# 2       BAJAJ PULSAR NS 200                758            POLISH
# 3       BAJAJ PULSAR NS 200                758       CONSUMABLES
# 4       BAJAJ PULSAR NS 200                758       COOLANT OIL

# %%
df.size
# Out:
# 199374

# %%
df.shape
# Out:
# (28482, 7)

# %%
df.describe()
# Out:
#        invoice_date job_card_date business_partner_name  vehicle_no  \
# count         28482         28482                 28482       28482
# unique          555           553                  1010         846
# top        01-12-18      01-12-18        venkXXXXXXXXXX  KA53EVXXXX
# freq            179           179                   424        1313
#
#            vehicle_model current_km_reading invoice_line_text
# count              28482              28482             28476
# unique                28               3474               503
# top     BAJAJ PULSAR 150                  0        ENGINE OIL
# freq                8633                842              3802

# %%
data=df.copy()

# %%
df.drop(['job_card_date','business_partner_name','vehicle_no'],axis=1,inplace=True)

# %%
df.head(5)
# Out:
#   invoice_date             vehicle_model current_km_reading invoice_line_text
# 0     30-05-17  BAJAJ AVENGER STREET 220              50000        ENGINE OIL
# 1     02-06-17       BAJAJ PULSAR NS 200                758        ENGINE OIL
# 2     02-06-17       BAJAJ PULSAR NS 200                758            POLISH
# 3     02-06-17       BAJAJ PULSAR NS 200                758       CONSUMABLES
# 4     02-06-17       BAJAJ PULSAR NS 200                758       COOLANT OIL

# %%
new_data=df[['invoice_date','invoice_line_text']]

# %%
new_data
# Out:
#       invoice_date invoice_line_text
# 0         30-05-17        ENGINE OIL
# 1         02-06-17        ENGINE OIL
# 2         02-06-17            POLISH
# 3         02-06-17       CONSUMABLES
# 4         02-06-17       COOLANT OIL
# ...            ...               ...
# 28477     06-01-19   SPROCKET RUBBER
# 28478     06-01-19      CLUTCH CABLE
# 28479     06-01-19        OIL FILTER
# 28480     06-01-19          DISC OIL
# 28481     06-01-19        AIR FILTER
#
# [28482 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# invoice_date          0
# vehicle_model         0
# current_km_reading    0
# invoice_line_text     6
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28482 entries, 0 to 28481
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   invoice_date        28482 non-null  object
#  1   vehicle_model       28482 non-null  object
#  2   current_km_reading  28482 non-null  object
#  3   invoice_line_text   28476 non-null  object
# dtypes: object(4)
# memory usage: 890.2+ KB

# %%
list(df.invoice_line_text)
# Out:
# ['ENGINE OIL',
#  'ENGINE OIL',
#  'POLISH',
#  'CONSUMABLES',
#  'COOLANT OIL',
#  'CHAIN LUBRICATION',
#  '4 WAY SWITCH',
#  'ENGINE OIL',
#  '3M OIL',
#  'CHAIN LUBRICATION',
#  'GENERAL SERVICE',
#  'ENGINE OIL',
#  'OIL FILTER',
#  'ENGINE OIL',
#  'ENGINE OIL',
#  '3M OIL',
#  'CHAIN LUBRICATION',
#  'INDICATOR',
#  'HEAD REST',
#  'VALVE GUIDE',
#  'TIMMING CHAIN',
#  'FOOT REST',
#  'LOW BEAM BULB',
#  'VALVE GRAINDING',
#  'DISC PAD',
#  'LOADING GEAR',
#  'PACKING KIT',
#  'TIMMING CHAIN PAD',
#  'TENSIONER',
#  'CLUTCH BELL REST',
#  'ENGINE OIL',
#  'CLUTCH ASSEMBLY',
#  'VALVE KIT',
#  'SPARK PLUG',
#  'ONE WAY CLUTCH',
#  'BORE KIT',
#  'AIR FILTER',
#  'HEAD RUBBER',
#  'CLUTCH CABLE',
#  'CRANK SHAFT',
#  'DISC PAD',
#  'BRAKE ADJUSTMENT',
#  'GENERAL SERVICE',
#  'BRAKE ADJUSTMENT',
#  'HEAD RUBBER',
#  '3M OIL',
#  'CHAIN LUBRICATION',
#  'BRAKE SHOE',
#  'ENGINE OIL',
#  'AIR FILTER CHECKUP',
#  'ENGINE OIL',
#  'AIR FILTER CHECKUP',
#  'CHAIN LUBRICATION',
# ...
